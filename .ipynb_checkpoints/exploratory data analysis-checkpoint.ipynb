# %%
import pandas as pd

# %%
# read data
data = pd.read_csv('databl.csv',sep=';') # use ; separator
data.head()
# Out:
#    response  platform  category_name condition  stock  \
# 1         0         0            438       new      9
# 2         0         1            484       new      4
# 3         0         0              1       new      3
# 4         0         0            131       new      6
# 5         0         1            247       new      3
#
#    free_shipping_coverage_count  courier_count  view_count  \
# 1                             0              5           3
# 2                             0              3           0
# 3                             2              2          36
# 4                             0             12         102
# 5                             0             15          88
#
#    seller_delivery_response_time  favorite_count      ...       varSeller_6  \
# 1                       3.811863               0      ...              11.0
# 2                            NaN               0      ...               NaN
# ...

# %%
# get data general information

# %%
# how many row and col
data.shape
# Out:
# (259347, 30)

# %%
# detail information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 259347 entries, 1 to 259347
# Data columns (total 30 columns):
# response                         259347 non-null int64
# platform                         259347 non-null int64
# category_name                    259347 non-null int64
# condition                        259347 non-null object
# stock                            259347 non-null int64
# free_shipping_coverage_count     259347 non-null int64
# courier_count                    259347 non-null int64
# view_count                       259347 non-null int64
# seller_delivery_response_time    240371 non-null float64
# favorite_count                   259347 non-null int64
# sold                             259347 non-null int64
# varUser_1                        258483 non-null float64
# varUser_2                        259347 non-null int64
# varUser_3                        259347 non-null int64
# varUser_4                        259347 non-null int64
# ...

# %%
# there is many null data, especially on varSeller_7

# %%
print(data.drop_duplicates().shape)
print(data.shape)
print(data.shape[0]-data.drop_duplicates().shape[0])
# Out:
# (258310, 30)
# (259347, 30)
# 1037

# %%
# there is 1037 duplicates data

# %%
data.columns.tolist()
# Out:
# ['response',
#  'platform',
#  'category_name',
#  'condition',
#  'stock',
#  'free_shipping_coverage_count',
#  'courier_count',
#  'view_count',
#  'seller_delivery_response_time',
#  'favorite_count',
#  'sold',
#  'varUser_1',
#  'varUser_2',
#  'varUser_3',
#  'varUser_4',
#  'varSeller_1',
#  'varSeller_2',
#  'varSeller_3',
#  'varSeller_4',
#  'varSeller_5',
#  'varSeller_6',
#  'varSeller_7',
#  'varSeller_8',
#  'varSeller_9',
#  'varProduct_1',
#  'varProduct_2',
#  'varProduct_3',
#  'varProduct_4',
#  'varProduct_5',
#  'varGeneral_1']

# %%
# select known kolom data
data_2 = data[data.columns.tolist()[:11]]
data_2.head()
# Out:
#    response  platform  category_name condition  stock  \
# 1         0         0            438       new      9
# 2         0         1            484       new      4
# 3         0         0              1       new      3
# 4         0         0            131       new      6
# 5         0         1            247       new      3
#
#    free_shipping_coverage_count  courier_count  view_count  \
# 1                             0              5           3
# 2                             0              3           0
# 3                             2              2          36
# 4                             0             12         102
# 5                             0             15          88
#
#    seller_delivery_response_time  favorite_count  sold
# 1                       3.811863               0     2
# 2                            NaN               0     0
# 3                       2.880625               4     2
# 4                       2.341068             236    48
# ...
